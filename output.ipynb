# %%
import pandas as pd

# %% [markdown]
# # Receive Input

# %%
def prepare_input_data(file_path):
    df = pd.read_csv('output.txt')
    
    index_of_pred = (df == 'predicciones').idxmax().observaciones
    
    df_in = df.iloc[:index_of_pred].copy()
    df_in[['observacion', 'U', 'V', 'T']] = df_in['observaciones'].str.split(expand=True)
    df_in.drop(columns=['observaciones', 'T'], inplace=True)
    df_in = df_in.astype(int)
    
    df_out = df.iloc[index_of_pred + 1:].copy()
    df_out.rename({'observaciones': 'predicciones'}, axis=1, inplace=True)
    df_out[['fecha', 'hora', 'U', 'V', 'T']] = df_out['predicciones'].str.split(expand=True)
    df_out['date_time'] = pd.to_datetime(df_out['fecha'] + ' ' + df_out['hora'], format='%Y-%m-%d %H:%M')
    df_out.drop(columns=['predicciones', 'T', 'fecha', 'hora'], inplace=True)
    df_out = df_out[['date_time', 'U', 'V']] 
    df_out = df_out.astype({'U': 'int', 'V': 'int64'})
    df = df.sort_values(by='date_time')
    
    return df_in, df_out

# %%
ob_df, pred_df = prepare_input_data('output.txt')

display(ob_df, pred_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [132], line 1
# ----> 1 ob_df, pred_df = prepare_input_data('output.txt')
#       3 display(ob_df, pred_df)
#
# Cell In [131], line 18, in prepare_input_data(file_path)
#      16 df_out = df_out[['date_time', 'U', 'V']]
#      17 df_out = df_out.astype({'U': 'int', 'V': 'int64'})
# ---> 18 df['date_time'] = pd.to_datetime(df['date_time'])
#      19 df = df.sort_values(by='date_time')
#      21 return df_in, df_out
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'date_time'

# %%
pred_df.dtypes
# Out:
# datetime    datetime64[ns]
# U                    int64
# V                    int64
# dtype: object

# %%
pred_df = pred_df.astype({'U': 'int', 'V': 'int64'})

# %%
df = pd.read_csv('output.txt')

index_of_pred = (df == 'predicciones').idxmax().observaciones

df_out = df.iloc[index_of_pred + 1:].copy()
df_out.rename({'observaciones': 'predicciones'}, axis=1, inplace=True)
df_out
# Out:
#                     predicciones
# 457  2009-10-25 23:00 -10 3 2902
# 458  2009-10-20 14:00 -9 -9 2897
# 459  2009-10-25 23:00 -10 3 2902
# 460  2009-10-20 14:00 -9 -9 2897
# 461  2009-10-25 23:00 -10 3 2902
# 462  2009-10-20 14:00 -9 -9 2897
# 463  2009-10-25 23:00 -10 3 2902
# 464  2009-10-20 14:00 -9 -9 2897
# 465  2009-10-25 23:00 -10 3 2902
# 466  2009-10-20 14:00 -9 -9 2897
# 467  2009-10-25 23:00 -10 3 2902
# 468  2009-10-20 14:00 -9 -9 2897
# 469  2009-10-25 23:00 -10 3 2902
# 470  2009-10-20 14:00 -9 -9 2897
# 471  2009-10-25 23:00 -10 3 2902
# 472  2009-10-20 14:00 -9 -9 2897
# 473  2009-10-25 23:00 -10 3 2902
# 474  2009-10-20 14:00 -9 -9 2897

# %%
df_out[['fecha', 'hora', 'U', 'V', 'T']] = df_out['predicciones'].str.split(expand=True)
df_out
# Out:
#                     predicciones       fecha   hora    U   V     T
# 457  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 458  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 459  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 460  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 461  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 462  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 463  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 464  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 465  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 466  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 467  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 468  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 469  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 470  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 471  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 472  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 473  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 474  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897

# %%
df_out['date_time'] = pd.to_datetime(df_out['fecha'] + ' ' + df_out['hora'], format='%Y-%m-%d %H:%M')
df_out
# Out:
#                     predicciones       fecha   hora    U   V     T  \
# 457  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 458  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 459  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 460  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 461  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 462  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 463  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 464  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 465  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 466  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 467  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 468  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 469  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 470  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 471  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 472  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
# 473  2009-10-25 23:00 -10 3 2902  2009-10-25  23:00  -10   3  2902
# 474  2009-10-20 14:00 -9 -9 2897  2009-10-20  14:00   -9  -9  2897
#
#               date_time
# 457 2009-10-25 23:00:00
# 458 2009-10-20 14:00:00
# 459 2009-10-25 23:00:00
# 460 2009-10-20 14:00:00
# 461 2009-10-25 23:00:00
# 462 2009-10-20 14:00:00
# 463 2009-10-25 23:00:00
# 464 2009-10-20 14:00:00
# 465 2009-10-25 23:00:00
# 466 2009-10-20 14:00:00
# 467 2009-10-25 23:00:00
# 468 2009-10-20 14:00:00
# 469 2009-10-25 23:00:00
# 470 2009-10-20 14:00:00
# 471 2009-10-25 23:00:00
# 472 2009-10-20 14:00:00
# 473 2009-10-25 23:00:00
# 474 2009-10-20 14:00:00

# %%
df_out.drop(columns=['predicciones', 'T', 'fecha', 'hora'], inplace=True)
df_out
# Out:
#        U   V           date_time
# 457  -10   3 2009-10-25 23:00:00
# 458   -9  -9 2009-10-20 14:00:00
# 459  -10   3 2009-10-25 23:00:00
# 460   -9  -9 2009-10-20 14:00:00
# 461  -10   3 2009-10-25 23:00:00
# 462   -9  -9 2009-10-20 14:00:00
# 463  -10   3 2009-10-25 23:00:00
# 464   -9  -9 2009-10-20 14:00:00
# 465  -10   3 2009-10-25 23:00:00
# 466   -9  -9 2009-10-20 14:00:00
# 467  -10   3 2009-10-25 23:00:00
# 468   -9  -9 2009-10-20 14:00:00
# 469  -10   3 2009-10-25 23:00:00
# 470   -9  -9 2009-10-20 14:00:00
# 471  -10   3 2009-10-25 23:00:00
# 472   -9  -9 2009-10-20 14:00:00
# 473  -10   3 2009-10-25 23:00:00
# 474   -9  -9 2009-10-20 14:00:00

# %%
df_out.dtypes
# Out:
# U                    object
# V                    object
# date_time    datetime64[ns]
# dtype: object

# %%
df_out = df_out[['date_time', 'U', 'V']]
df_out
# Out:
#               date_time    U   V
# 457 2009-10-25 23:00:00  -10   3
# 458 2009-10-20 14:00:00   -9  -9
# 459 2009-10-25 23:00:00  -10   3
# 460 2009-10-20 14:00:00   -9  -9
# 461 2009-10-25 23:00:00  -10   3
# 462 2009-10-20 14:00:00   -9  -9
# 463 2009-10-25 23:00:00  -10   3
# 464 2009-10-20 14:00:00   -9  -9
# 465 2009-10-25 23:00:00  -10   3
# 466 2009-10-20 14:00:00   -9  -9
# 467 2009-10-25 23:00:00  -10   3
# 468 2009-10-20 14:00:00   -9  -9
# 469 2009-10-25 23:00:00  -10   3
# 470 2009-10-20 14:00:00   -9  -9
# 471 2009-10-25 23:00:00  -10   3
# 472 2009-10-20 14:00:00   -9  -9
# 473 2009-10-25 23:00:00  -10   3
# 474 2009-10-20 14:00:00   -9  -9

# %%
df_out = df_out.astype({'U': 'int', 'V': 'int64'})
df_out.dtypes
# Out:
# date_time    datetime64[ns]
# U                     int64
# V                     int64
# dtype: object

# %%
# # Corrected column name here
# df_out['date_time'] = pd.to_datetime(df_out['date_time'])
# df_out.dtypes

# %%
df_out = df_out.sort_values(by='date_time')
df_out
# Out:
#               date_time   U  V
# 474 2009-10-20 14:00:00  -9 -9
# 458 2009-10-20 14:00:00  -9 -9
# 472 2009-10-20 14:00:00  -9 -9
# 460 2009-10-20 14:00:00  -9 -9
# 462 2009-10-20 14:00:00  -9 -9
# 470 2009-10-20 14:00:00  -9 -9
# 464 2009-10-20 14:00:00  -9 -9
# 466 2009-10-20 14:00:00  -9 -9
# 468 2009-10-20 14:00:00  -9 -9
# 471 2009-10-25 23:00:00 -10  3
# 469 2009-10-25 23:00:00 -10  3
# 457 2009-10-25 23:00:00 -10  3
# 473 2009-10-25 23:00:00 -10  3
# 463 2009-10-25 23:00:00 -10  3
# 461 2009-10-25 23:00:00 -10  3
# 459 2009-10-25 23:00:00 -10  3
# 467 2009-10-25 23:00:00 -10  3
# 465 2009-10-25 23:00:00 -10  3

# %%
ob_df, pred_df = prepare_input_data('output.txt')

display(ob_df, pred_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [135], line 1
# ----> 1 ob_df, pred_df = prepare_input_data('output.txt')
#       3 display(ob_df, pred_df)
#
# Cell In [134], line 22, in prepare_input_data(file_path)
#      19 df_out = df_out.astype({'U': 'int', 'V': 'int64'})
#      21 # Corrected column name here
# ---> 22 df_out['date_time'] = pd.to_datetime(df_out['date_time'])
#      23 df_out = df_out.sort_values(by='date_time')
#      25 return df_in, df_out
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'date_time'
